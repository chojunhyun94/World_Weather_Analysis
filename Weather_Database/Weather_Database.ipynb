# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = lat_lngs

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
   
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?appid="+ weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | da lat
# Processing Record 2 of Set 1 | lorengau
# Processing Record 3 of Set 1 | sargodha
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | barranca
# Processing Record 13 of Set 1 | padang
# Processing Record 14 of Set 1 | cayenne
# Processing Record 15 of Set 1 | esperance
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | novikovo
# Processing Record 18 of Set 1 | omboue
# Processing Record 19 of Set 1 | namibe
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 1 | samarai
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | campana
# Processing Record 28 of Set 1 | mexico
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | hasaki
# Processing Record 31 of Set 1 | kaitangata
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | rawson
# Processing Record 34 of Set 1 | surgana
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | upernavik
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | komsomolets
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | ilulissat
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | kungsbacka
# Processing Record 47 of Set 1 | ocampo
# Processing Record 48 of Set 1 | linhares
# Processing Record 49 of Set 1 | aklavik
# Processing Record 50 of Set 1 | pangnirtung
# Processing Record 1 of Set 2 | longyearbyen
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | hami
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | kyshtovka
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | tete
# Processing Record 8 of Set 2 | whitecourt
# Processing Record 9 of Set 2 | chalchihuites
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | anchorage
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | quatre cocos
# Processing Record 15 of Set 2 | bilma
# Processing Record 16 of Set 2 | oda
# Processing Record 17 of Set 2 | bilibino
# Processing Record 18 of Set 2 | klaksvik
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 2 | portland
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | conde
# Processing Record 25 of Set 2 | faya
# Processing Record 26 of Set 2 | ceres
# Processing Record 27 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 2 | catacamas
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | saint-joseph
# Processing Record 31 of Set 2 | margate
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | leningradskiy
# Processing Record 34 of Set 2 | ahipara
# Processing Record 35 of Set 2 | mareeba
# Processing Record 36 of Set 2 | praya
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | jaciara
# Processing Record 39 of Set 2 | shihezi
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | ilebo
# Processing Record 43 of Set 2 | atuona
# Processing Record 44 of Set 2 | carangola
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 2 | srikakulam
# Processing Record 48 of Set 2 | manta
# Processing Record 49 of Set 2 | busselton
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | broome
# Processing Record 2 of Set 3 | jalu
# Processing Record 3 of Set 3 | ginir
# Processing Record 4 of Set 3 | invercargill
# Processing Record 5 of Set 3 | buala
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | katangli
# Processing Record 10 of Set 3 | nossa senhora da gloria
# Processing Record 11 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | pevek
# Processing Record 14 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 3 | nizhniy tsasuchey
# Processing Record 16 of Set 3 | ngunguru
# Processing Record 17 of Set 3 | furukawa
# Processing Record 18 of Set 3 | vostok
# Processing Record 19 of Set 3 | port blair
# Processing Record 20 of Set 3 | ust-nera
# Processing Record 21 of Set 3 | asfi
# Processing Record 22 of Set 3 | berkakit
# Processing Record 23 of Set 3 | west helena
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | hermanus
# Processing Record 26 of Set 3 | mezen
# Processing Record 27 of Set 3 | nioro
# Processing Record 28 of Set 3 | pisco
# Processing Record 29 of Set 3 | san pedro
# Processing Record 30 of Set 3 | yar-sale
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | lavrentiya
# Processing Record 33 of Set 3 | mwense
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | fare
# Processing Record 36 of Set 3 | along
# Processing Record 37 of Set 3 | khani
# Processing Record 38 of Set 3 | ostrovnoy
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | lishu
# Processing Record 41 of Set 3 | vallenar
# Processing Record 42 of Set 3 | san patricio
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | cabo san lucas
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | tucuman
# Processing Record 47 of Set 3 | irtyshskiy
# Processing Record 48 of Set 3 | esfarayen
# Processing Record 49 of Set 3 | madang
# Processing Record 50 of Set 3 | zyryanka
# Processing Record 1 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 4 | eyl
# Processing Record 3 of Set 4 | hithadhoo
# Processing Record 4 of Set 4 | sur
# Processing Record 5 of Set 4 | chavakkad
# Processing Record 6 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 4 | alice springs
# Processing Record 8 of Set 4 | tuktoyaktuk
# Processing Record 9 of Set 4 | bathsheba
# Processing Record 10 of Set 4 | kirovskiy
# Processing Record 11 of Set 4 | isangel
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | waingapu
# Processing Record 14 of Set 4 | vila velha
# Processing Record 15 of Set 4 | peoria
# Processing Record 16 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 4 | diapaga
# Processing Record 18 of Set 4 | keti bandar
# Processing Record 19 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 4 | ostersund
# Processing Record 21 of Set 4 | imbituba
# Processing Record 22 of Set 4 | iracoubo
# Processing Record 23 of Set 4 | ust-omchug
# Processing Record 24 of Set 4 | talnakh
# Processing Record 25 of Set 4 | seoul
# Processing Record 26 of Set 4 | pandamatenga
# Processing Record 27 of Set 4 | bowen
# Processing Record 28 of Set 4 | santiago
# Processing Record 29 of Set 4 | lufilufi
# Processing Record 30 of Set 4 | tilichiki
# Processing Record 31 of Set 4 | touros
# Processing Record 32 of Set 4 | coahuayana
# Processing Record 33 of Set 4 | cabra
# Processing Record 34 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 4 | torbay
# Processing Record 36 of Set 4 | adrar
# Processing Record 37 of Set 4 | penzance
# Processing Record 38 of Set 4 | emba
# Processing Record 39 of Set 4 | urucara
# Processing Record 40 of Set 4 | saint george
# Processing Record 41 of Set 4 | gorontalo
# Processing Record 42 of Set 4 | surab
# Processing Record 43 of Set 4 | stornoway
# Processing Record 44 of Set 4 | sao jose da coroa grande
# Processing Record 45 of Set 4 | ballina
# Processing Record 46 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 4 | yerbogachen
# Processing Record 48 of Set 4 | okha
# Processing Record 49 of Set 4 | kerman
# Processing Record 50 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 5 | kununurra
# Processing Record 2 of Set 5 | prokudskoye
# Processing Record 3 of Set 5 | hurghada
# Processing Record 4 of Set 5 | geraldton
# Processing Record 5 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 5 | neiafu
# Processing Record 7 of Set 5 | nome
# Processing Record 8 of Set 5 | vestmannaeyjar
# Processing Record 9 of Set 5 | nacala
# Processing Record 10 of Set 5 | upata
# Processing Record 11 of Set 5 | constitucion
# Processing Record 12 of Set 5 | kamaishi
# Processing Record 13 of Set 5 | zandvoort
# Processing Record 14 of Set 5 | tres arroyos
# Processing Record 15 of Set 5 | fort nelson
# Processing Record 16 of Set 5 | morris
# Processing Record 17 of Set 5 | necochea
# Processing Record 18 of Set 5 | awbari
# Processing Record 19 of Set 5 | merauke
# Processing Record 20 of Set 5 | laguna
# Processing Record 21 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 5 | maua
# Processing Record 23 of Set 5 | tautira
# Processing Record 24 of Set 5 | ostashkov
# Processing Record 25 of Set 5 | chapleau
# Processing Record 26 of Set 5 | parana
# Processing Record 27 of Set 5 | pontes e lacerda
# Processing Record 28 of Set 5 | zaplyusye
# City not found. Skipping...
# Processing Record 29 of Set 5 | cidreira
# Processing Record 30 of Set 5 | letka
# Processing Record 31 of Set 5 | kloulklubed
# Processing Record 32 of Set 5 | namatanai
# Processing Record 33 of Set 5 | kodiak
# Processing Record 34 of Set 5 | guarapari
# Processing Record 35 of Set 5 | araouane
# Processing Record 36 of Set 5 | flinders
# Processing Record 37 of Set 5 | nikolskoye
# Processing Record 38 of Set 5 | grand-santi
# Processing Record 39 of Set 5 | sao joao da barra
# Processing Record 40 of Set 5 | ambunti
# Processing Record 41 of Set 5 | foix
# Processing Record 42 of Set 5 | hyeres
# Processing Record 43 of Set 5 | lompoc
# Processing Record 44 of Set 5 | lasa
# Processing Record 45 of Set 5 | los llanos de aridane
# Processing Record 46 of Set 5 | dalgopol
# Processing Record 47 of Set 5 | port-gentil
# Processing Record 48 of Set 5 | voh
# Processing Record 49 of Set 5 | cherskiy
# Processing Record 50 of Set 5 | katherine
# Processing Record 1 of Set 6 | carutapera
# Processing Record 2 of Set 6 | saint-gaudens
# Processing Record 3 of Set 6 | luderitz
# Processing Record 4 of Set 6 | ahuimanu
# Processing Record 5 of Set 6 | northam
# Processing Record 6 of Set 6 | qianguo
# Processing Record 7 of Set 6 | asau
# Processing Record 8 of Set 6 | manokwari
# Processing Record 9 of Set 6 | oktyabrskoye
# Processing Record 10 of Set 6 | heihe
# Processing Record 11 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 6 | sinnamary
# Processing Record 13 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 6 | rocha
# Processing Record 15 of Set 6 | bayan
# Processing Record 16 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 6 | mbuji-mayi
# Processing Record 18 of Set 6 | kathu
# Processing Record 19 of Set 6 | campbell river
# Processing Record 20 of Set 6 | kintampo
# Processing Record 21 of Set 6 | monteiro
# Processing Record 22 of Set 6 | dingle
# Processing Record 23 of Set 6 | save
# Processing Record 24 of Set 6 | deputatskiy
# Processing Record 25 of Set 6 | victoria
# Processing Record 26 of Set 6 | matara
# Processing Record 27 of Set 6 | severo-kurilsk
# Processing Record 28 of Set 6 | bambous virieux
# Processing Record 29 of Set 6 | gat
# Processing Record 30 of Set 6 | talara
# Processing Record 31 of Set 6 | kirakira
# Processing Record 32 of Set 6 | harper
# Processing Record 33 of Set 6 | ratnagiri
# Processing Record 34 of Set 6 | alcudia
# Processing Record 35 of Set 6 | loiza
# Processing Record 36 of Set 6 | guerrero negro
# Processing Record 37 of Set 6 | vanimo
# Processing Record 38 of Set 6 | marienburg
# Processing Record 39 of Set 6 | south daytona
# Processing Record 40 of Set 6 | antofagasta
# Processing Record 41 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 6 | oistins
# Processing Record 43 of Set 6 | yucca valley
# Processing Record 44 of Set 6 | meadville
# Processing Record 45 of Set 6 | luwuk
# Processing Record 46 of Set 6 | iqaluit
# Processing Record 47 of Set 6 | baglung
# Processing Record 48 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 49 of Set 6 | lebu
# Processing Record 50 of Set 6 | san rafael
# Processing Record 1 of Set 7 | tsaratanana
# Processing Record 2 of Set 7 | mayo
# Processing Record 3 of Set 7 | coban
# Processing Record 4 of Set 7 | tiksi
# Processing Record 5 of Set 7 | umm kaddadah
# Processing Record 6 of Set 7 | rorvik
# Processing Record 7 of Set 7 | walvis bay
# Processing Record 8 of Set 7 | alofi
# Processing Record 9 of Set 7 | deniliquin
# Processing Record 10 of Set 7 | camacha
# Processing Record 11 of Set 7 | biharamulo
# Processing Record 12 of Set 7 | lipari
# Processing Record 13 of Set 7 | nouadhibou
# Processing Record 14 of Set 7 | shakiso
# Processing Record 15 of Set 7 | berlevag
# Processing Record 16 of Set 7 | chara
# Processing Record 17 of Set 7 | varkaus
# Processing Record 18 of Set 7 | panaba
# Processing Record 19 of Set 7 | banda aceh
# Processing Record 20 of Set 7 | ponta do sol
# Processing Record 21 of Set 7 | fortuna
# Processing Record 22 of Set 7 | port lincoln
# Processing Record 23 of Set 7 | botevgrad
# Processing Record 24 of Set 7 | hongjiang
# Processing Record 25 of Set 7 | leh
# Processing Record 26 of Set 7 | san ramon
# Processing Record 27 of Set 7 | askiz
# Processing Record 28 of Set 7 | billings
# Processing Record 29 of Set 7 | lishui
# Processing Record 30 of Set 7 | the pas
# Processing Record 31 of Set 7 | thinadhoo
# Processing Record 32 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 7 | mariestad
# Processing Record 34 of Set 7 | bandarbeyla
# Processing Record 35 of Set 7 | atar
# Processing Record 36 of Set 7 | kalispell
# Processing Record 37 of Set 7 | morondava
# Processing Record 38 of Set 7 | turka
# Processing Record 39 of Set 7 | lenine
# Processing Record 40 of Set 7 | aykhal
# Processing Record 41 of Set 7 | khatanga
# Processing Record 42 of Set 7 | pimentel
# Processing Record 43 of Set 7 | ushtobe
# Processing Record 44 of Set 7 | salalah
# Processing Record 45 of Set 7 | port-cartier
# Processing Record 46 of Set 7 | grindavik
# Processing Record 47 of Set 7 | bousso
# Processing Record 48 of Set 7 | contamana
# Processing Record 49 of Set 7 | drumheller
# Processing Record 50 of Set 7 | klyuchi
# Processing Record 1 of Set 8 | kashi
# Processing Record 2 of Set 8 | san quintin
# Processing Record 3 of Set 8 | bahir dar
# Processing Record 4 of Set 8 | san francisco
# Processing Record 5 of Set 8 | nishihara
# Processing Record 6 of Set 8 | nanortalik
# Processing Record 7 of Set 8 | brae
# Processing Record 8 of Set 8 | cape canaveral
# Processing Record 9 of Set 8 | doctor arroyo
# Processing Record 10 of Set 8 | lavumisa
# Processing Record 11 of Set 8 | hofn
# Processing Record 12 of Set 8 | gisborne
# Processing Record 13 of Set 8 | ovruch
# Processing Record 14 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 8 | plettenberg bay
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | matata
# Processing Record 18 of Set 8 | wittlich
# Processing Record 19 of Set 8 | san cristobal
# Processing Record 20 of Set 8 | ouesso
# Processing Record 21 of Set 8 | santarem
# Processing Record 22 of Set 8 | dovolnoye
# Processing Record 23 of Set 8 | ashford
# Processing Record 24 of Set 8 | provideniya
# Processing Record 25 of Set 8 | tiarei
# Processing Record 26 of Set 8 | waipawa
# Processing Record 27 of Set 8 | kedrovyy
# Processing Record 28 of Set 8 | narsaq
# Processing Record 29 of Set 8 | romny
# Processing Record 30 of Set 8 | sikasso
# Processing Record 31 of Set 8 | katsuura
# Processing Record 32 of Set 8 | saint anthony
# Processing Record 33 of Set 8 | zhangjiakou
# Processing Record 34 of Set 8 | marsh harbour
# Processing Record 35 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 36 of Set 8 | caceres
# Processing Record 37 of Set 8 | kapit
# Processing Record 38 of Set 8 | shieli
# Processing Record 39 of Set 8 | isla vista
# Processing Record 40 of Set 8 | benguela
# Processing Record 41 of Set 8 | bhag
# Processing Record 42 of Set 8 | inhambane
# Processing Record 43 of Set 8 | jiayuguan
# Processing Record 44 of Set 8 | bull savanna
# Processing Record 45 of Set 8 | teguise
# Processing Record 46 of Set 8 | vila franca do campo
# Processing Record 47 of Set 8 | birao
# Processing Record 48 of Set 8 | vao
# Processing Record 49 of Set 8 | ono
# Processing Record 50 of Set 8 | camopi
# Processing Record 1 of Set 9 | arcelia
# Processing Record 2 of Set 9 | seddon
# Processing Record 3 of Set 9 | komsomolskiy
# Processing Record 4 of Set 9 | riyadh
# Processing Record 5 of Set 9 | san juan
# Processing Record 6 of Set 9 | bemidji
# Processing Record 7 of Set 9 | codrington
# Processing Record 8 of Set 9 | iskateley
# Processing Record 9 of Set 9 | itarema
# Processing Record 10 of Set 9 | puerto maldonado
# Processing Record 11 of Set 9 | takoradi
# Processing Record 12 of Set 9 | lam luk ka
# Processing Record 13 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 14 of Set 9 | chunskiy
# Processing Record 15 of Set 9 | puerto escondido
# Processing Record 16 of Set 9 | freeport
# Processing Record 17 of Set 9 | palmer
# Processing Record 18 of Set 9 | buon me thuot
# City not found. Skipping...
# Processing Record 19 of Set 9 | montrose
# Processing Record 20 of Set 9 | qeshm
# Processing Record 21 of Set 9 | olafsvik
# Processing Record 22 of Set 9 | saldanha
# Processing Record 23 of Set 9 | dovers
# Processing Record 24 of Set 9 | tual
# Processing Record 25 of Set 9 | bulgan
# Processing Record 26 of Set 9 | bonga
# Processing Record 27 of Set 9 | hirara
# Processing Record 28 of Set 9 | sicamous
# Processing Record 29 of Set 9 | placido de castro
# Processing Record 30 of Set 9 | krasnyy chikoy
# Processing Record 31 of Set 9 | alihe
# Processing Record 32 of Set 9 | sevsk
# Processing Record 33 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 9 | tonstad
# Processing Record 35 of Set 9 | vysokogornyy
# Processing Record 36 of Set 9 | sao filipe
# Processing Record 37 of Set 9 | yuanping
# Processing Record 38 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 9 | sumenep
# Processing Record 40 of Set 9 | havre-saint-pierre
# Processing Record 41 of Set 9 | labytnangi
# Processing Record 42 of Set 9 | progreso
# Processing Record 43 of Set 9 | kazanskaya
# Processing Record 44 of Set 9 | half moon bay
# Processing Record 45 of Set 9 | talawdi
# City not found. Skipping...
# Processing Record 46 of Set 9 | red bluff
# Processing Record 47 of Set 9 | algiers
# Processing Record 48 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 49 of Set 9 | abha
# Processing Record 50 of Set 9 | dawson creek
# Processing Record 1 of Set 10 | comodoro rivadavia
# Processing Record 2 of Set 10 | kyabram
# Processing Record 3 of Set 10 | manzhouli
# Processing Record 4 of Set 10 | little current
# Processing Record 5 of Set 10 | bijie
# Processing Record 6 of Set 10 | mbini
# Processing Record 7 of Set 10 | lagoa
# Processing Record 8 of Set 10 | mogadishu
# Processing Record 9 of Set 10 | usinsk
# Processing Record 10 of Set 10 | giyon
# Processing Record 11 of Set 10 | arroyo
# Processing Record 12 of Set 10 | port hardy
# Processing Record 13 of Set 10 | kaoma
# Processing Record 14 of Set 10 | saint-francois
# Processing Record 15 of Set 10 | ekibastuz
# Processing Record 16 of Set 10 | flin flon
# Processing Record 17 of Set 10 | qandala
# Processing Record 18 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 10 | soyo
# Processing Record 20 of Set 10 | dobre miasto
# Processing Record 21 of Set 10 | kahului
# Processing Record 22 of Set 10 | bonavista
# Processing Record 23 of Set 10 | sangar
# Processing Record 24 of Set 10 | mount gambier
# Processing Record 25 of Set 10 | udachnyy
# Processing Record 26 of Set 10 | gurupi
# Processing Record 27 of Set 10 | tura
# Processing Record 28 of Set 10 | pak phanang
# Processing Record 29 of Set 10 | pacific grove
# Processing Record 30 of Set 10 | mopipi
# Processing Record 31 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 10 | izumo
# Processing Record 33 of Set 10 | san
# Processing Record 34 of Set 10 | khor
# Processing Record 35 of Set 10 | skegness
# Processing Record 36 of Set 10 | kushima
# Processing Record 37 of Set 10 | balotra
# Processing Record 38 of Set 10 | linxia
# Processing Record 39 of Set 10 | husavik
# Processing Record 40 of Set 10 | moyale
# Processing Record 41 of Set 10 | itaberaba
# Processing Record 42 of Set 10 | natal
# Processing Record 43 of Set 10 | inirida
# Processing Record 44 of Set 10 | yulara
# Processing Record 45 of Set 10 | angoche
# Processing Record 46 of Set 10 | fairbanks
# Processing Record 47 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 10 | athabasca
# Processing Record 49 of Set 10 | puerto cabezas
# Processing Record 50 of Set 10 | yumen
# Processing Record 1 of Set 11 | liverpool
# Processing Record 2 of Set 11 | burica
# City not found. Skipping...
# Processing Record 3 of Set 11 | dunedin
# Processing Record 4 of Set 11 | pekan
# Processing Record 5 of Set 11 | henties bay
# Processing Record 6 of Set 11 | kulhudhuffushi
# Processing Record 7 of Set 11 | coquimbo
# Processing Record 8 of Set 11 | itoman
# Processing Record 9 of Set 11 | lakatoro
# Processing Record 10 of Set 11 | chippenham
# Processing Record 11 of Set 11 | mehamn
# Processing Record 12 of Set 11 | belyy yar
# Processing Record 13 of Set 11 | shimoda
# Processing Record 14 of Set 11 | sanandaj
# Processing Record 15 of Set 11 | uvira
# Processing Record 16 of Set 11 | clearwater
# Processing Record 17 of Set 11 | surgut
# Processing Record 18 of Set 11 | phalaborwa
# Processing Record 19 of Set 11 | mahajanga
# Processing Record 20 of Set 11 | ishigaki
# Processing Record 21 of Set 11 | port augusta
# Processing Record 22 of Set 11 | neijiang
# Processing Record 23 of Set 11 | sept-iles
# Processing Record 24 of Set 11 | tezu
# Processing Record 25 of Set 11 | flagstaff
# Processing Record 26 of Set 11 | gold coast
# Processing Record 27 of Set 11 | sitka
# Processing Record 28 of Set 11 | nsunga
# Processing Record 29 of Set 11 | banes
# Processing Record 30 of Set 11 | urumqi
# Processing Record 31 of Set 11 | ilhabela
# Processing Record 32 of Set 11 | barcelos
# Processing Record 33 of Set 11 | berdigestyakh
# Processing Record 34 of Set 11 | sibolga
# Processing Record 35 of Set 11 | vagur
# Processing Record 36 of Set 11 | chadan
# Processing Record 37 of Set 11 | batsfjord
# Processing Record 38 of Set 11 | clyde river
# Processing Record 39 of Set 11 | bolobo
# Processing Record 40 of Set 11 | shenjiamen
# Processing Record 41 of Set 11 | tarnogskiy gorodok
# Processing Record 42 of Set 11 | north bend
# Processing Record 43 of Set 11 | champerico
# Processing Record 44 of Set 11 | kachiry
# Processing Record 45 of Set 11 | turukhansk
# Processing Record 46 of Set 11 | lincoln
# Processing Record 47 of Set 11 | damaturu
# Processing Record 48 of Set 11 | tuatapere
# Processing Record 49 of Set 11 | madarounfa
# Processing Record 50 of Set 11 | ust-tsilma
# Processing Record 1 of Set 12 | acapulco
# Processing Record 2 of Set 12 | te anau
# Processing Record 3 of Set 12 | pokhara
# Processing Record 4 of Set 12 | dorokhovo
# Processing Record 5 of Set 12 | basco
# Processing Record 6 of Set 12 | whitianga
# Processing Record 7 of Set 12 | khorramshahr
# Processing Record 8 of Set 12 | vila
# Processing Record 9 of Set 12 | mount darwin
# Processing Record 10 of Set 12 | kimberley
# Processing Record 11 of Set 12 | magadan
# Processing Record 12 of Set 12 | nevsehir
# Processing Record 13 of Set 12 | boa vista
# Processing Record 14 of Set 12 | corinth
# Processing Record 15 of Set 12 | malampaka
# Processing Record 16 of Set 12 | miandrivazo
# Processing Record 17 of Set 12 | cairns
# Processing Record 18 of Set 12 | marquette
# Processing Record 19 of Set 12 | bereda
# Processing Record 20 of Set 12 | okhotsk
# Processing Record 21 of Set 12 | huangzhai
# Processing Record 22 of Set 12 | acajutla
# Processing Record 23 of Set 12 | alekseyevka
# Processing Record 24 of Set 12 | la asuncion
# Processing Record 25 of Set 12 | sistranda
# Processing Record 26 of Set 12 | kargasok
# Processing Record 27 of Set 12 | shache
# Processing Record 28 of Set 12 | pierre
# Processing Record 29 of Set 12 | haines junction
# Processing Record 30 of Set 12 | kutum
# Processing Record 31 of Set 12 | znamensk
# Processing Record 32 of Set 12 | zhigansk
# Processing Record 33 of Set 12 | santa rosa
# Processing Record 34 of Set 12 | pereira barreto
# Processing Record 35 of Set 12 | naze
# Processing Record 36 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 37 of Set 12 | norton shores
# Processing Record 38 of Set 12 | kruisfontein
# Processing Record 39 of Set 12 | phitsanulok
# Processing Record 40 of Set 12 | santa fe
# Processing Record 41 of Set 12 | newtonmore
# Processing Record 42 of Set 12 | sobolevo
# Processing Record 43 of Set 12 | axim
# Processing Record 44 of Set 12 | gwanda
# Processing Record 45 of Set 12 | rio grande
# Processing Record 46 of Set 12 | lazaro cardenas
# Processing Record 47 of Set 12 | launceston
# Processing Record 48 of Set 12 | saint-pierre
# Processing Record 49 of Set 12 | cabedelo
# Processing Record 50 of Set 12 | owando
# Processing Record 1 of Set 13 | nurota
# Processing Record 2 of Set 13 | jiuquan
# Processing Record 3 of Set 13 | egvekinot
# Processing Record 4 of Set 13 | kasongo-lunda
# Processing Record 5 of Set 13 | aksu
# Processing Record 6 of Set 13 | meulaboh
# Processing Record 7 of Set 13 | nantucket
# Processing Record 8 of Set 13 | taltal
# Processing Record 9 of Set 13 | burgos
# Processing Record 10 of Set 13 | kyren
# Processing Record 11 of Set 13 | padre paraiso
# Processing Record 12 of Set 13 | mejicanos
# Processing Record 13 of Set 13 | waitati
# Processing Record 14 of Set 13 | pemangkat
# Processing Record 15 of Set 13 | jiwani
# Processing Record 16 of Set 13 | borodyanka
# Processing Record 17 of Set 13 | jerome
# Processing Record 18 of Set 13 | akkudah
# City not found. Skipping...
# Processing Record 19 of Set 13 | motygino
# Processing Record 20 of Set 13 | chase
# Processing Record 21 of Set 13 | calabar
# Processing Record 22 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 13 | liyang
# Processing Record 24 of Set 13 | la paz
# Processing Record 25 of Set 13 | kirsanov
# Processing Record 26 of Set 13 | khasan
# Processing Record 27 of Set 13 | kaihua
# Processing Record 28 of Set 13 | maracai
# Processing Record 29 of Set 13 | gladstone
# Processing Record 30 of Set 13 | akdepe
# Processing Record 31 of Set 13 | nabire
# Processing Record 32 of Set 13 | mordovo
# Processing Record 33 of Set 13 | chapais
# Processing Record 34 of Set 13 | boddam
# Processing Record 35 of Set 13 | aksarayskiy
# Processing Record 36 of Set 13 | nara
# Processing Record 37 of Set 13 | matay
# Processing Record 38 of Set 13 | armacao de pera
# Processing Record 39 of Set 13 | opuwo
# Processing Record 40 of Set 13 | cascais
# Processing Record 41 of Set 13 | bolshaya sosnova
# Processing Record 42 of Set 13 | yelizovo
# Processing Record 43 of Set 13 | oranjemund
# Processing Record 44 of Set 13 | tanda
# Processing Record 45 of Set 13 | jardim
# Processing Record 46 of Set 13 | cap malheureux
# Processing Record 47 of Set 13 | wewak
# Processing Record 48 of Set 13 | kisanga
# Processing Record 49 of Set 13 | kurilsk
# Processing Record 50 of Set 13 | mutare
# Processing Record 1 of Set 14 | senovo
# Processing Record 2 of Set 14 | ogbomosho
# Processing Record 3 of Set 14 | shasta lake
# Processing Record 4 of Set 14 | whitehorse
# Processing Record 5 of Set 14 | kibala
# Processing Record 6 of Set 14 | cururupu
# Processing Record 7 of Set 14 | uglovskoye
# Processing Record 8 of Set 14 | show low
# Processing Record 9 of Set 14 | kyrnasivka
# Processing Record 10 of Set 14 | guerrero
# Processing Record 11 of Set 14 | bonthe
# Processing Record 12 of Set 14 | akhtanizovskaya
# Processing Record 13 of Set 14 | boyolangu
# Processing Record 14 of Set 14 | rawah
# Processing Record 15 of Set 14 | kabinda
# Processing Record 16 of Set 14 | corinto
# Processing Record 17 of Set 14 | ourem
# Processing Record 18 of Set 14 | maragogi
# Processing Record 19 of Set 14 | matamoros
# Processing Record 20 of Set 14 | awjilah
# Processing Record 21 of Set 14 | goshen
# Processing Record 22 of Set 14 | belmonte
# Processing Record 23 of Set 14 | srednekolymsk
# Processing Record 24 of Set 14 | payo
# Processing Record 25 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 14 | kungurtug
# Processing Record 27 of Set 14 | auki
# Processing Record 28 of Set 14 | newport
# Processing Record 29 of Set 14 | kabare
# Processing Record 30 of Set 14 | katakwi
# Processing Record 31 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 32 of Set 14 | cikupa
# Processing Record 33 of Set 14 | coihaique
# Processing Record 34 of Set 14 | gombong
# Processing Record 35 of Set 14 | savinka
# Processing Record 36 of Set 14 | mingguang
# Processing Record 37 of Set 14 | duldurga
# Processing Record 38 of Set 14 | pudozh
# Processing Record 39 of Set 14 | entre rios
# Processing Record 40 of Set 14 | bossangoa
# Processing Record 41 of Set 14 | zavetnoye
# Processing Record 42 of Set 14 | shakawe
# Processing Record 43 of Set 14 | zhuzhou
# Processing Record 44 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 45 of Set 14 | verkhnevilyuysk
# Processing Record 46 of Set 14 | haverfordwest
# Processing Record 47 of Set 14 | hualmay
# Processing Record 48 of Set 14 | kiyasovo
# Processing Record 49 of Set 14 | dabrowa gornicza
# Processing Record 50 of Set 14 | tornio
# Processing Record 1 of Set 15 | mashhad
# Processing Record 2 of Set 15 | porosozero
# Processing Record 3 of Set 15 | dongsheng
# Processing Record 4 of Set 15 | camana
# Processing Record 5 of Set 15 | yatou
# Processing Record 6 of Set 15 | christchurch
# Processing Record 7 of Set 15 | tarata
# Processing Record 8 of Set 15 | moron
# Processing Record 9 of Set 15 | nuuk
# Processing Record 10 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 15 | arlit
# Processing Record 12 of Set 15 | alghero
# Processing Record 13 of Set 15 | badian
# Processing Record 14 of Set 15 | richards bay
# Processing Record 15 of Set 15 | kaniama
# Processing Record 16 of Set 15 | leopoldina
# Processing Record 17 of Set 15 | chumikan
# Processing Record 18 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 20 of Set 15 | durant
# Processing Record 21 of Set 15 | dingzhou
# Processing Record 22 of Set 15 | koshki
# Processing Record 23 of Set 15 | torit
# Processing Record 24 of Set 15 | taretan
# Processing Record 25 of Set 15 | tselinnoye
# Processing Record 26 of Set 15 | yenagoa
# Processing Record 27 of Set 15 | dapaong
# Processing Record 28 of Set 15 | kaabong
# Processing Record 29 of Set 15 | morros
# Processing Record 30 of Set 15 | salinas
# Processing Record 31 of Set 15 | kalabo
# Processing Record 32 of Set 15 | bjornevatn
# Processing Record 33 of Set 15 | mount isa
# Processing Record 34 of Set 15 | nanakuli
# Processing Record 35 of Set 15 | amahai
# Processing Record 36 of Set 15 | pingliang
# Processing Record 37 of Set 15 | angoram
# Processing Record 38 of Set 15 | esil
# Processing Record 39 of Set 15 | kisangani
# Processing Record 40 of Set 15 | fredericksburg
# Processing Record 41 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 15 | chicama
# Processing Record 43 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 15 | acari
# Processing Record 45 of Set 15 | grand gaube
# Processing Record 46 of Set 15 | ulaanbaatar
# Processing Record 47 of Set 15 | vestmanna
# Processing Record 48 of Set 15 | vaxjo
# Processing Record 49 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 15 | karatuzskoye
# Processing Record 1 of Set 16 | whithorn
# Processing Record 2 of Set 16 | omsukchan
# Processing Record 3 of Set 16 | feldkirchen an der donau
# Processing Record 4 of Set 16 | bluefield
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Da Lat  11.9465  108.4419    292.97        77          99
# 1         Lorengau  -2.0226  147.2712    302.14        71          94
# 2         Sargodha  32.0836   72.6711    286.84        66           0
# 3       Bredasdorp -34.5322   20.0403    289.04        66         100
# 4            Kapaa  22.0752 -159.3190    301.14        72          40
# 5             Hilo  19.7297 -155.0900    297.94        88         100
# 6   Port Elizabeth -33.9180   25.5701    289.87        83          38
# 7  Arraial Do Cabo -22.9661  -42.0278    296.22        94         100
# 8          Rikitea -23.1203 -134.9692    297.00        81         100
# 9           Avarua -21.2078 -159.7750    298.18        61          60
#
#    Wind Speed Country Current Description
# 0        1.76      VN     overcast clouds
# 1        1.31      PG     overcast clouds
# 2        2.38      PK           clear sky
# 3        3.30      ZA     overcast clouds
# 4        6.69      US    scattered clouds
# 5        3.60      US       moderate rain
# 6        5.11      ZA    scattered clouds
# 7       11.67      BR       moderate rain
# 8        6.43      PF     overcast clouds
# 9        6.17      CK       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reorder = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reorder]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Da Lat      VN  11.9465  108.4419    292.97        77          99
# 1         Lorengau      PG  -2.0226  147.2712    302.14        71          94
# 2         Sargodha      PK  32.0836   72.6711    286.84        66           0
# 3       Bredasdorp      ZA -34.5322   20.0403    289.04        66         100
# 4            Kapaa      US  22.0752 -159.3190    301.14        72          40
# 5             Hilo      US  19.7297 -155.0900    297.94        88         100
# 6   Port Elizabeth      ZA -33.9180   25.5701    289.87        83          38
# 7  Arraial Do Cabo      BR -22.9661  -42.0278    296.22        94         100
# 8          Rikitea      PF -23.1203 -134.9692    297.00        81         100
# 9           Avarua      CK -21.2078 -159.7750    298.18        61          60
#
#    Wind Speed Current Description
# 0        1.76     overcast clouds
# 1        1.31     overcast clouds
# 2        2.38           clear sky
# 3        3.30     overcast clouds
# 4        6.69    scattered clouds
# 5        3.60       moderate rain
# 6        5.11    scattered clouds
# 7       11.67       moderate rain
# 8        6.43     overcast clouds
# 9        6.17       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
file_to_save = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(file_to_save)
